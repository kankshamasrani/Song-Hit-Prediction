# %% [markdown]
# #TWITTER
# ---

# %%
from pattern.web    import Twitter
from pattern.en     import tag
from pattern.vector import KNN, count

twitter, knn = Twitter(), KNN()


for tweet in twitter.search('#Moksha2015', start=1, count=100):
    s = tweet.text.lower()
    print tweet
# Out:
# Result({u'profile': u'http://pbs.twimg.com/profile_images/457021896794460160/jKTF1Hkr_normal.jpeg', u'language': u'en', u'author': u'du_beat', u'url': u'https://twitter.com/du_beat/status/579619819387031552', u'text': u'Here are a few glimpses from Day 1 at #NSIT #Moksha2015. #FestSeason\nhttp://t.co/86UbBY3c6r', u'date': u'Sun Mar 22 12:25:08 +0000 2015', u'id': u'579619819387031552'})
# Result({u'profile': u'http://pbs.twimg.com/profile_images/556009876258705409/E494wdKY_normal.jpeg', u'language': u'da', u'author': u'divyashree_jena', u'url': u'https://twitter.com/divyashree_jena/status/579325598243381248', u'text': u'Blurred af. #moksha2015 https://t.co/pYWoDlyfcn', u'date': u'Sat Mar 21 16:56:00 +0000 2015', u'id': u'579325598243381248'})
# Result({u'profile': u'http://pbs.twimg.com/profile_images/457021896794460160/jKTF1Hkr_normal.jpeg', u'language': u'en', u'author': u'du_beat', u'url': u'https://twitter.com/du_beat/status/579190393050288128', u'text': u'@TheViralFever brought the house down on Day 1 of #Moksha2015, the annual fest of NSIT. http://t.co/nCM2VYZIWG', u'date': u'Sat Mar 21 07:58:45 +0000 2015', u'id': u'579190393050288128'})
# Result({u'profile': u'http://pbs.twimg.com/profile_images/570309096490795008/_VXCDRv9_normal.jpeg', u'language': u'en', u'author': u'nsitmoksha', u'url': u'https://twitter.com/nsitmoksha/status/579154885846773760', u'text': u'Day 2 at Moksha 2015 begins #Moksha2015', u'date': u'Sat Mar 21 05:37:39 +0000 2015', u'id': u'579154885846773760'})
# Result({u'profile': u'http://pbs.twimg.com/profile_images/423629912369401856/I5vX0wS5_normal.jpeg', u'language': u'es', u'author': u'MokshaJoyeria', u'url': u'https://twitter.com/MokshaJoyeria/status/579015633154809856', u'text': u'Tonos de primavera #hellospring #bohemian #moksha #handmade #joyasmexicanas #bohochic #moksha2015\u2026 https://t.co/DbMnm9LJrQ', u'date': u'Fri Mar 20 20:24:19 +0000 2015', u'id': u'579015633154809856'})

# %% [markdown]
# #Facebook
# ---

# %%
import os, sys; sys.path.insert(0, os.path.join(os.path.dirname('__file__'), "..", ".."))

from pattern.web import Facebook, NEWS, COMMENTS, LIKES
from pattern.db  import Datasheet, pprint, pd

# The Facebook API can be used to search public status updates (no license needed).

# It can also be used to get status updates, comments and persons that liked it,
# from a given profile or product page.
# This requires a personal license key.
# If you are logged in to Facebook, you can get a license key here:
# http://www.clips.ua.ac.be/pattern-facebook
# (We don't / can't store your information).

# 1) Searching for public status updates.
#    Search for all status updates that contain the word "horrible".

try: 
    # We'll store the status updates in a Datasheet.
    # A Datasheet is a table of rows and columns that can be exported as a CSV-file.
    # In the first column, we'll store a unique id for each status update.
    # We only want to add new status updates, i.e., those we haven't seen yet.
    # With an index on the first column we can quickly check if an id already exists.
    table = Datasheet.load(pd("opinions.csv"))
    index = set(table.columns[0])
except:
    table = Datasheet()
    index = set()

fb = Facebook()

# With Facebook.search(cached=False), a "live" request is sent to Facebook:
# we get the most recent results instead of those in the local cache.
# Keeping a local cache can also be useful (e.g., while testing)
# because a query is instant when it is executed the second time.
# for status in fb.search("horrible", count=25, cached=False):
#     print "=" * 100
#     print status.id
#     print status.text
#     print status.author # Yields an (id, name)-tuple.
#     print status.date
#     print status.likes
#     print status.comments
#     print
#     # Only add the tweet to the table if it doesn't already exists.
#     if len(table) == 0 or status.id not in index:
#         table.append([status.id, status.text])
#         index.add(status.id)

# Create a .csv in pattern/examples/01-web/
table.save(pd("opinions.csv"))

# 2) Status updates from specific profiles.
#    For this you need a personal license key:
#    http://www.clips.ua.ac.be/pattern-facebook

license = "CAACEdEose0cBAErviQyJCNZCTDXZASO88ZALvC0jooL54fWlmdRBeIeOIPSXSt92twjT728k6CAROBbZCPoNIZCIAq953gP0eJhiT6JXEOzZBrPrAW967twuOJN2LXN3p3JgryFoukZBNzL4xSIA4yoPHaLBRZA8JeNLvgjk8F7hk0jLfghepK2kKf0IUlc4DfrzcQSaG64ZC0x4LiOVICuP62GuZAwCQW4YQRJQD3JZA5v6wZDZD"

if license != "":
    fb = Facebook(license)
    # Facebook.profile() returns a dictionary with author info.
    # By default, this is your own profile. 
    # You can also supply the id of another profile, 
    # or the name of a product page.
    me = fb.profile()["id"]
    for status in fb.search(me, type=NEWS, count=30, cached=False):
        print "-" * 100
        print status.id    # Status update unique id.
        print status.title # Status title (i.e., the id of the page or event given as URL).
        print status.text  # Status update text.
        print status.url   # Status update image, external link, ...
        if status.comments > 0:
            # Retrieve comments on the status update.
            print "%s comments:" % status.comments
            print [(x.author, x.text, x.likes) for x in fb.search(status.id, type=COMMENTS)]
        if status.likes > 0:
            # Retrieve likes on the status update.
            print "%s likes:" % status.likes
            print [x.author for x in fb.search(status.id, type=LIKES)]
        print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4013cf700668> in <module>()
#      63     # You can also supply the id of another profile,
#      64     # or the name of a product page.
# ---> 65     me = fb.profile()["id"]
#      66     for status in fb.search(me, type=NEWS, count=30, cached=False):
#      67         print "-" * 100
#
# TypeError: tuple indices must be integers, not str

# %%
import facebook
import requests

def some_action(post):
    """ Here you might want to do something with each post. E.g. grab the
    post's message (post['message']) or the post's picture (post['picture']).
    In this implementation we just print the post's created time.
    """
    print post['created_time']


# You'll need an access token here to do anything.  You can get a temporary one
# here: https://developers.facebook.com/tools/explorer/
access_token = 'CAACEdEose0cBAFfwcd1uhIEy3ZBiwzTZAOlZCEU67aZCyvSlZAESYLZBae9KPbwcEldCsdiXgsr1TLBvv40MyenCmGlpKzS82uieo0nyJCDYsGGyVUc2rZBaAw2znjlEg8ppiLEXc39ctoP63sR1knkmdOwpbKxwcPGoEYrZCqjxEFcJ0SXxOhH6925JoSLZAKm8eZBlAKkGNSNDqL23ZCDs8ZB9c1iHFlTqf68ZD'
# Look at Bill Gates's profile for this example by using his Facebook id.
user = 'BillGates'

graph = facebook.GraphAPI(access_token)
profile = graph.get_object(user)
posts = graph.get_connections(profile['id'], 'posts')

# Wrap this block in a while loop so we can keep paginating requests until
# finished.
while True:
    try:
        # Perform some action on each post in the collection we receive from
        # Facebook.
        [some_action(post=post) for post in posts['data']]
        # Attempt to make a request to the next page of data, if it exists.
        posts = requests.get(posts['paging']['next']).json()
        print posts
    except KeyError:
        # When there are no more pages (['paging']['next']), break from the
        # loop and end the script.
        break
# Out:
# 2015-03-21T21:52:13+0000
# 2015-03-20T16:40:21+0000
# 2015-03-20T04:15:08+0000
# 2015-03-19T23:17:44+0000
# 2015-03-19T15:43:43+0000
# 2015-03-18T23:07:46+0000
# 2015-03-18T15:06:31+0000
# 2015-03-18T04:41:01+0000
# 2015-03-17T23:00:24+0000
# 2015-03-17T11:55:10+0000
# 2015-03-16T23:35:05+0000
# 2015-03-14T05:01:08+0000
# 2015-03-13T15:10:52+0000
# 2015-03-12T12:10:28+0000
# 2015-03-11T21:02:18+0000
# 2015-03-11T15:24:13+0000
# 2015-03-10T23:31:01+0000
# 2015-03-09T14:45:43+0000
# 2015-03-07T16:35:06+0000
# 2015-03-06T18:31:05+0000
# 2015-03-05T20:43:27+0000
# 2015-03-05T19:08:46+0000
# 2015-03-04T16:05:20+0000
# 2015-03-04T06:05:15+0000
# 2015-03-03T01:06:51+0000
# hi
# 2015-02-28T17:35:16+0000
# 2015-02-28T01:45:20+0000
# 2015-02-25T22:05:13+0000
# 2015-02-25T18:23:52+0000
# 2015-02-24T23:30:01+0000
# 2015-02-20T11:35:16+0000
# 2015-02-19T14:10:15+0000
# 2015-02-18T21:05:11+0000
# 2015-02-18T16:12:53+0000
# 2015-02-13T23:31:03+0000
# 2015-02-13T14:50:37+0000
# 2015-02-13T05:20:19+0000
# 2015-02-12T23:10:13+0000
# 2015-02-12T16:50:26+0000
# 2015-02-11T18:45:41+0000
# 2015-02-11T02:35:06+0000
# 2015-02-10T17:08:27+0000
# 2015-02-10T01:01:51+0000
# 2015-02-07T18:25:19+0000
# 2015-02-06T14:25:11+0000
# 2015-02-06T06:35:07+0000
# 2015-02-04T16:29:41+0000
# 2015-02-03T21:35:12+0000
# 2015-02-03T14:05:25+0000
# 2015-02-03T06:00:44+0000
# hi
# 2015-02-02T18:50:12+0000
# 2015-01-31T21:05:19+0000
# 2015-01-31T13:50:18+0000
# 2015-01-30T17:01:22+0000
# 2015-01-30T05:55:12+0000
# 2015-01-29T19:35:31+0000
# 2015-01-29T04:25:09+0000
# 2015-01-28T18:35:02+0000
# 2015-01-28T00:05:17+0000
# 2015-01-27T17:16:48+0000
# 2015-01-26T19:00:01+0000
# 2015-01-26T14:05:23+0000
# 2015-01-26T00:00:37+0000
# 2015-01-25T16:20:16+0000
# 2015-01-24T21:25:09+0000
# 2015-01-24T16:00:01+0000
# 2015-01-23T17:23:13+0000
# 2015-01-23T00:58:57+0000
# 2015-01-22T17:02:06+0000
# 2015-01-22T13:00:35+0000
# 2015-01-22T03:30:00+0000
# 2015-01-17T18:05:13+0000
# 2015-01-16T20:00:50+0000
# 2015-01-16T14:05:10+0000
# 2015-01-15T23:34:23+0000
# hi
# 2015-01-08T00:19:34+0000
# 2015-01-07T14:10:22+0000
# 2015-01-06T23:41:13+0000
# 2015-01-02T14:10:27+0000
# 2014-12-31T14:30:47+0000
# 2014-12-30T17:15:27+0000
# 2014-12-29T19:47:30+0000
# 2014-12-27T16:01:04+0000
# 2014-12-24T09:00:50+0000
# 2014-12-24T02:30:11+0000
# 2014-12-23T01:32:57+0000
# 2014-12-21T21:00:33+0000
# 2014-12-19T23:00:12+0000
# 2014-12-19T20:30:22+0000
# 2014-12-18T14:11:24+0000
# 2014-12-18T02:30:37+0000
# 2014-12-17T20:14:50+0000
# 2014-12-16T14:05:23+0000
# 2014-12-16T02:08:24+0000
# 2014-12-14T21:00:49+0000
# 2014-12-13T17:05:30+0000
# 2014-12-12T23:30:37+0000
# 2014-12-12T14:20:27+0000
# 2014-12-11T00:15:29+0000
# 2014-12-10T07:01:05+0000
# hi
# 2014-12-09T20:10:36+0000
# 2014-12-09T14:01:52+0000
# 2014-12-08T22:58:46+0000
# 2014-12-08T18:09:28+0000
# 2014-12-05T12:00:00+0000
# 2014-12-04T13:55:18+0000
# 2014-12-03T14:10:24+0000
# 2014-12-03T00:31:39+0000
# 2014-12-02T17:35:37+0000
# 2014-12-02T16:30:11+0000
# 2014-12-02T02:31:05+0000
# 2014-12-01T23:25:36+0000
# 2014-12-01T19:54:48+0000
# 2014-11-26T18:15:29+0000
# 2014-11-26T13:55:19+0000
# 2014-11-25T14:05:11+0000
# 2014-11-22T01:07:30+0000
# 2014-11-21T14:15:27+0000
# 2014-11-20T04:01:04+0000
# 2014-11-19T22:03:45+0000
# 2014-11-18T14:01:02+0000
# 2014-11-14T14:10:24+0000
# 2014-11-13T14:01:22+0000
# 2014-11-13T07:00:23+0000
# 2014-11-12T21:15:14+0000
# hi
# 2014-11-10T14:30:54+0000
# 2014-11-10T04:05:14+0000
# 2014-11-06T17:08:37+0000
# 2014-11-05T22:38:12+0000
# 2014-11-04T20:01:37+0000
# 2014-11-04T13:50:36+0000
# 2014-11-04T01:45:58+0000
# 2014-11-03T04:40:12+0000
# 2014-10-31T15:35:20+0000
# 2014-10-30T15:05:35+0000
# 2014-10-30T08:05:12+0000
# 2014-10-28T21:53:01+0000
# 2014-10-28T20:21:20+0000
# 2014-10-28T16:31:43+0000
# 2014-10-27T02:57:30+0000
# 2014-10-24T15:01:59+0000
# 2014-10-24T12:25:15+0000
# 2014-10-23T23:27:50+0000
# 2014-10-23T12:55:23+0000
# 2014-10-23T08:01:34+0000
# 2014-10-22T17:25:21+0000
# 2014-10-22T01:30:15+0000
# 2014-10-20T17:13:32+0000
# 2014-10-16T13:33:11+0000
# 2014-10-15T12:45:25+0000
# hi
# 2014-10-14T23:22:48+0000
# 2014-10-13T23:08:24+0000
# 2014-10-10T19:02:40+0000
# 2014-10-10T05:30:12+0000
# 2014-10-09T16:46:39+0000
# 2014-10-08T15:30:40+0000
# 2014-10-07T02:30:28+0000
# 2014-10-06T15:24:45+0000
# 2014-10-04T15:15:34+0000
# 2014-10-03T13:05:39+0000
# 2014-10-01T15:56:04+0000
# 2014-10-01T02:32:45+0000
# 2014-09-29T22:31:07+0000
# 2014-09-29T20:08:17+0000
# 2014-09-26T07:25:11+0000
# 2014-09-25T06:05:09+0000
# 2014-09-24T12:02:28+0000
# 2014-09-23T19:10:12+0000
# 2014-09-22T17:59:48+0000
# 2014-09-22T16:23:36+0000
# 2014-09-18T13:15:48+0000
# 2014-09-18T03:15:21+0000
# 2014-09-17T13:05:20+0000
# 2014-09-17T06:00:22+0000
# 2014-09-15T20:02:08+0000
# hi
# 2014-09-12T13:20:20+0000
# 2014-09-08T19:12:07+0000
# 2014-09-05T12:45:47+0000
# 2014-09-03T13:05:26+0000
# 2014-09-03T01:00:27+0000
# 2014-09-02T22:17:07+0000
# 2014-08-28T13:01:48+0000
# 2014-08-27T21:11:31+0000
# 2014-08-26T13:05:19+0000
# 2014-08-26T00:01:36+0000
# 2014-08-25T22:11:45+0000
# 2014-08-24T17:00:19+0000
# 2014-08-23T20:54:14+0000
# 2014-08-23T16:05:28+0000
# 2014-08-22T13:00:49+0000
# 2014-08-21T21:00:24+0000
# 2014-08-21T16:10:39+0000
# 2014-08-21T13:05:57+0000
# 2014-08-21T00:15:09+0000
# 2014-08-20T16:10:00+0000
# 2014-08-20T13:05:11+0000
# 2014-08-19T17:13:08+0000
# 2014-08-15T18:22:30+0000
# 2014-08-15T13:35:20+0000
# 2014-08-14T08:01:17+0000
# hi
# 2014-08-13T17:40:46+0000
# 2014-08-13T01:01:19+0000
# 2014-08-12T13:35:10+0000
# 2014-08-12T05:30:43+0000
# 2014-08-09T16:01:32+0000
# 2014-08-07T07:15:19+0000
# 2014-08-06T18:36:43+0000
# 2014-08-05T17:10:00+0000
# 2014-08-05T08:01:07+0000
# 2014-08-05T05:15:14+0000
# 2014-08-05T00:08:16+0000
# 2014-08-04T17:23:54+0000
# 2014-07-31T15:20:09+0000
# 2014-07-31T03:01:05+0000
# 2014-07-30T01:38:35+0000
# 2014-07-29T18:45:44+0000
# 2014-07-29T00:35:19+0000
# 2014-07-28T18:54:20+0000
# 2014-07-27T22:45:16+0000
# 2014-07-27T17:05:07+0000
# 2014-07-27T05:56:45+0000
# 2014-07-25T13:25:24+0000
# 2014-07-24T20:25:05+0000
# 2014-07-24T13:40:20+0000
# 2014-07-24T02:50:12+0000
# hi
# 2014-07-23T17:15:13+0000
# 2014-07-23T16:45:41+0000
# 2014-07-17T12:45:35+0000
# 2014-07-16T12:55:17+0000
# 2014-07-15T12:45:26+0000
# 2014-07-15T04:05:11+0000
# 2014-07-14T16:37:09+0000
# 2014-07-11T20:25:03+0000
# 2014-07-09T12:30:26+0000
# 2014-07-08T16:56:10+0000
# 2014-07-03T13:15:34+0000
# 2014-07-02T04:40:11+0000
# 2014-07-01T19:02:23+0000
# 2014-07-01T12:45:14+0000
# 2014-07-01T05:45:10+0000
# 2014-06-30T18:05:13+0000
# 2014-06-30T12:20:17+0000
# 2014-06-27T04:15:11+0000
# 2014-06-27T01:30:33+0000
# 2014-06-26T13:15:16+0000
# 2014-06-26T04:40:04+0000
# 2014-06-25T21:21:49+0000
# 2014-06-25T19:05:36+0000
# 2014-06-25T15:25:25+0000
# 2014-06-23T13:20:28+0000
# hi
# 2014-06-20T12:31:11+0000
# 2014-06-17T12:50:30+0000
# 2014-06-16T23:47:46+0000
# 2014-06-16T20:34:46+0000
# 2014-06-15T22:06:56+0000
# 2014-06-13T13:05:08+0000
# 2014-06-13T03:00:08+0000
# 2014-06-12T13:01:49+0000
# 2014-06-12T03:05:09+0000
# 2014-06-10T21:50:39+0000
# 2014-06-06T13:30:55+0000
# 2014-06-05T13:45:41+0000
# 2014-06-05T07:05:05+0000
# 2014-06-04T21:37:55+0000
# 2014-06-02T19:02:49+0000
# 2014-05-30T15:01:11+0000
# 2014-05-30T07:00:50+0000
# 2014-05-29T14:42:51+0000
# 2014-05-29T08:01:13+0000
# 2014-05-28T21:00:43+0000
# 2014-05-27T23:22:47+0000
# 2014-05-24T15:01:55+0000
# 2014-05-23T13:02:12+0000
# 2014-05-22T20:10:27+0000
# 2014-05-21T20:27:58+0000
# hi
# 2014-05-21T03:01:15+0000
# 2014-05-20T20:00:54+0000
# 2014-05-20T12:00:52+0000
# 2014-05-17T15:02:03+0000
# 2014-05-16T16:52:27+0000
# 2014-05-15T23:28:23+0000
# 2014-05-12T21:09:43+0000
# 2014-05-09T14:31:08+0000
# 2014-05-09T05:00:46+0000
# 2014-05-08T17:30:34+0000
# 2014-05-08T14:00:52+0000
# 2014-05-07T19:32:17+0000
# 2014-05-06T21:01:08+0000
# 2014-05-06T16:23:26+0000
# 2014-05-04T04:31:41+0000
# 2014-05-02T22:32:52+0000
# 2014-05-01T18:31:19+0000
# 2014-04-30T12:00:00+0000
# 2014-04-29T17:01:18+0000
# 2014-04-28T19:12:52+0000
# 2014-04-28T17:54:11+0000
# 2014-04-26T17:01:48+0000
# 2014-04-25T21:55:40+0000
# 2014-04-25T17:11:32+0000
# 2014-04-23T14:32:40+0000
# hi
# 2014-04-22T19:29:01+0000
# 2014-04-18T17:04:45+0000
# 2014-04-17T14:31:44+0000
# 2014-04-16T20:35:56+0000
# 2014-04-15T20:23:55+0000
# 2014-04-15T16:25:25+0000
# 2014-04-11T15:02:31+0000
# 2014-04-10T08:02:14+0000
# 2014-04-09T23:20:59+0000
# 2014-04-09T17:30:12+0000
# 2014-04-08T22:20:17+0000
# 2014-04-07T22:44:37+0000
# 2014-04-05T18:41:14+0000
# 2014-04-02T22:18:33+0000
# 2014-04-02T16:10:56+0000
# 2014-03-31T23:19:50+0000
# 2014-03-31T07:05:20+0000
# 2014-03-30T05:00:00+0000
# 2014-03-28T03:30:08+0000
# 2014-03-27T18:45:27+0000
# 2014-03-26T17:17:59+0000
# 2014-03-25T23:40:27+0000
# 2014-03-25T01:30:10+0000
# 2014-03-22T17:01:59+0000
# 2014-03-21T14:04:37+0000
# hi
